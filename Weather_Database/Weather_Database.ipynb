# %% [markdown]
# # Retrieve Weather Data for Random Set of Cities

# %% [markdown]
# ## Creating random set of latitudes & longitudes.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %% [markdown]
# ## Find corresponding city information.

# %%
# Import requests library and datetime module.
import requests
from datetime import datetime

# %%
# Import weather API key.
from config import weather_api_key

# %%
# Set up basic URL with api key
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f'{url}&q={city.replace(" ","+")}'

    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-" * 25)
print("Data Retrieval Complete      ")
print("-" * 25)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | liseleje
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | halifax
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | amot
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | derzhavinsk
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 14 of Set 1 | jubbal
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | belyy yar
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | qaqortoq
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | sinnar
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | bon air
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | gazanjyk
# Processing Record 27 of Set 1 | westport
# Processing Record 28 of Set 1 | beira
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | ust-omchug
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | sorland
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | korla
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | along
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | teguise
# Processing Record 47 of Set 1 | leningradskiy
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | tocache
# Processing Record 2 of Set 2 | gat
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | provideniya
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | alihe
# Processing Record 8 of Set 2 | kavaratti
# Processing Record 9 of Set 2 | bria
# Processing Record 10 of Set 2 | yulara
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | scarborough
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | nuevo laredo
# Processing Record 20 of Set 2 | sergeyevka
# Processing Record 21 of Set 2 | porbandar
# Processing Record 22 of Set 2 | tual
# Processing Record 23 of Set 2 | ust-koksa
# Processing Record 24 of Set 2 | innisfail
# Processing Record 25 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 2 | maceio
# Processing Record 27 of Set 2 | kulhudhuffushi
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | port-cartier
# Processing Record 34 of Set 2 | jining
# Processing Record 35 of Set 2 | isla vista
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | ribeira brava
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | fairbanks
# Processing Record 40 of Set 2 | khandyga
# Processing Record 41 of Set 2 | kahului
# Processing Record 42 of Set 2 | muros
# Processing Record 43 of Set 2 | alofi
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | lumphat
# Processing Record 46 of Set 2 | port lincoln
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | zhangye
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | cortes
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 3 | bonfim
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | udachnyy
# Processing Record 12 of Set 3 | nishihara
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | jambi
# Processing Record 16 of Set 3 | begunitsy
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | ust-nera
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | tilichiki
# Processing Record 21 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | rio gallegos
# Processing Record 24 of Set 3 | shemonaikha
# Processing Record 25 of Set 3 | tahta
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | takoradi
# Processing Record 28 of Set 3 | mering
# Processing Record 29 of Set 3 | chernyshkovskiy
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | pringsewu
# Processing Record 32 of Set 3 | beysehir
# Processing Record 33 of Set 3 | batagay-alyta
# Processing Record 34 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 3 | tanete
# Processing Record 36 of Set 3 | naze
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | japura
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | timaru
# Processing Record 42 of Set 3 | severo-kurilsk
# Processing Record 43 of Set 3 | pointe michel
# Processing Record 44 of Set 3 | comodoro rivadavia
# Processing Record 45 of Set 3 | bauchi
# Processing Record 46 of Set 3 | the valley
# Processing Record 47 of Set 3 | jinka
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | bontang
# Processing Record 50 of Set 3 | bay roberts
# Processing Record 1 of Set 4 | abu dhabi
# Processing Record 2 of Set 4 | husavik
# Processing Record 3 of Set 4 | toora-khem
# Processing Record 4 of Set 4 | vega de alatorre
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | kolpashevo
# Processing Record 7 of Set 4 | mosquera
# Processing Record 8 of Set 4 | corn island
# Processing Record 9 of Set 4 | vallenar
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | charleston
# Processing Record 12 of Set 4 | hobyo
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | kieta
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | visby
# Processing Record 17 of Set 4 | havelock
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | invermere
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | sanjwal
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | kollam
# Processing Record 24 of Set 4 | ahipara
# Processing Record 25 of Set 4 | sao felix do xingu
# Processing Record 26 of Set 4 | urumqi
# Processing Record 27 of Set 4 | pak phanang
# Processing Record 28 of Set 4 | fukagawa
# Processing Record 29 of Set 4 | brae
# Processing Record 30 of Set 4 | moanda
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | praia da vitoria
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | karad
# Processing Record 35 of Set 4 | whitehorse
# Processing Record 36 of Set 4 | bonavista
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | umm lajj
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | la spezia
# Processing Record 41 of Set 4 | verl
# Processing Record 42 of Set 4 | vila
# Processing Record 43 of Set 4 | port hedland
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | bilma
# Processing Record 47 of Set 4 | morro bay
# Processing Record 48 of Set 4 | saint-ambroise
# Processing Record 49 of Set 4 | areka
# Processing Record 50 of Set 4 | two rivers
# Processing Record 1 of Set 5 | west bay
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | arrecife
# Processing Record 4 of Set 5 | kirillov
# Processing Record 5 of Set 5 | cabra
# Processing Record 6 of Set 5 | kudahuvadhoo
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | marica
# Processing Record 10 of Set 5 | sur
# Processing Record 11 of Set 5 | riviere-au-renard
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | dabakala
# Processing Record 14 of Set 5 | san cristobal
# Processing Record 15 of Set 5 | aktash
# Processing Record 16 of Set 5 | baykit
# Processing Record 17 of Set 5 | arman
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | lata
# Processing Record 20 of Set 5 | lebu
# Processing Record 21 of Set 5 | yangjiang
# Processing Record 22 of Set 5 | sayville
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | axim
# Processing Record 25 of Set 5 | verkhneuralsk
# Processing Record 26 of Set 5 | pudozh
# Processing Record 27 of Set 5 | jaguarao
# Processing Record 28 of Set 5 | cayenne
# Processing Record 29 of Set 5 | lagos de moreno
# Processing Record 30 of Set 5 | safakulevo
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | tarauaca
# Processing Record 34 of Set 5 | trincomalee
# Processing Record 35 of Set 5 | zyryanskoye
# Processing Record 36 of Set 5 | malanville
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | richards bay
# Processing Record 39 of Set 5 | deer lake
# Processing Record 40 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | lashio
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | puerto baquerizo moreno
# Processing Record 46 of Set 5 | guarapari
# Processing Record 47 of Set 5 | cockburn town
# Processing Record 48 of Set 5 | port elizabeth
# Processing Record 49 of Set 5 | lazaro cardenas
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | tampico
# Processing Record 3 of Set 6 | smidovich
# Processing Record 4 of Set 6 | salinopolis
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | xian
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | mount pleasant
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | hammerfest
# Processing Record 12 of Set 6 | mongar
# Processing Record 13 of Set 6 | marquette
# Processing Record 14 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 15 of Set 6 | porosozero
# Processing Record 16 of Set 6 | shwebo
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | magistralnyy
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | matara
# Processing Record 21 of Set 6 | antalaha
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | beringovskiy
# Processing Record 24 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | beaupre
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | lincoln
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | aban
# Processing Record 32 of Set 6 | mackay
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | garagoa
# Processing Record 35 of Set 6 | beruwala
# Processing Record 36 of Set 6 | kropotkin
# Processing Record 37 of Set 6 | neryungri
# Processing Record 38 of Set 6 | tangwani
# Processing Record 39 of Set 6 | zheleznodorozhnyy
# Processing Record 40 of Set 6 | ciudad bolivar
# Processing Record 41 of Set 6 | kaoma
# Processing Record 42 of Set 6 | gambela
# Processing Record 43 of Set 6 | huaicheng
# Processing Record 44 of Set 6 | jieshi
# Processing Record 45 of Set 6 | saint-philippe
# Processing Record 46 of Set 6 | killam
# Processing Record 47 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | shelburne
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | erenhot
# Processing Record 1 of Set 7 | dongsheng
# Processing Record 2 of Set 7 | aitape
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | cauquenes
# Processing Record 5 of Set 7 | jacareacanga
# Processing Record 6 of Set 7 | altay
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | san andres
# Processing Record 9 of Set 7 | kiunga
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | taloqan
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | port hardy
# Processing Record 14 of Set 7 | pemangkat
# Processing Record 15 of Set 7 | rovnoye
# Processing Record 16 of Set 7 | basco
# Processing Record 17 of Set 7 | talara
# Processing Record 18 of Set 7 | vanavara
# Processing Record 19 of Set 7 | cap malheureux
# Processing Record 20 of Set 7 | raudeberg
# Processing Record 21 of Set 7 | coquimbo
# Processing Record 22 of Set 7 | awbari
# Processing Record 23 of Set 7 | kyren
# Processing Record 24 of Set 7 | port alberni
# Processing Record 25 of Set 7 | pervoye maya
# Processing Record 26 of Set 7 | puerto leguizamo
# Processing Record 27 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 7 | daru
# Processing Record 29 of Set 7 | florida
# Processing Record 30 of Set 7 | lumut
# Processing Record 31 of Set 7 | tripoli
# Processing Record 32 of Set 7 | skovde
# City not found. Skipping...
# Processing Record 33 of Set 7 | garowe
# Processing Record 34 of Set 7 | bonthe
# Processing Record 35 of Set 7 | iquique
# Processing Record 36 of Set 7 | bowen
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | victoria
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | eirunepe
# Processing Record 41 of Set 7 | phan thiet
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | carauari
# Processing Record 44 of Set 7 | mustasaari
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | yichun
# Processing Record 47 of Set 7 | yenagoa
# Processing Record 48 of Set 7 | resistencia
# Processing Record 49 of Set 7 | zonguldak
# Processing Record 50 of Set 7 | atherton
# Processing Record 1 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 8 | guaira
# Processing Record 4 of Set 8 | tiarei
# Processing Record 5 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 8 | shubarshi
# Processing Record 7 of Set 8 | aykhal
# Processing Record 8 of Set 8 | yablonovo
# Processing Record 9 of Set 8 | vangaindrano
# Processing Record 10 of Set 8 | pacific grove
# Processing Record 11 of Set 8 | inirida
# Processing Record 12 of Set 8 | shimoda
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | coahuayana
# Processing Record 15 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 8 | lorengau
# Processing Record 17 of Set 8 | sapa
# Processing Record 18 of Set 8 | san ramon
# Processing Record 19 of Set 8 | puerto del rosario
# Processing Record 20 of Set 8 | batemans bay
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | poum
# Processing Record 23 of Set 8 | mangrol
# Processing Record 24 of Set 8 | mineral wells
# Processing Record 25 of Set 8 | rafraf
# Processing Record 26 of Set 8 | mount gambier
# Processing Record 27 of Set 8 | alanya
# Processing Record 28 of Set 8 | mashivka
# Processing Record 29 of Set 8 | porto novo
# Processing Record 30 of Set 8 | lithgow
# Processing Record 31 of Set 8 | sodertalje
# City not found. Skipping...
# Processing Record 32 of Set 8 | amahai
# Processing Record 33 of Set 8 | frecatei
# Processing Record 34 of Set 8 | warrnambool
# Processing Record 35 of Set 8 | tagusao
# Processing Record 36 of Set 8 | sao pedro do sul
# Processing Record 37 of Set 8 | lubbock
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | kaabong
# Processing Record 40 of Set 8 | cururupu
# Processing Record 41 of Set 8 | hasaki
# Processing Record 42 of Set 8 | pafos
# Processing Record 43 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 8 | wanaka
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 8 | padang
# Processing Record 48 of Set 8 | lubao
# Processing Record 49 of Set 8 | kukmor
# Processing Record 50 of Set 8 | bairiki
# Processing Record 1 of Set 9 | deming
# Processing Record 2 of Set 9 | kikwit
# Processing Record 3 of Set 9 | tottori
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | peleduy
# Processing Record 6 of Set 9 | pyapon
# Processing Record 7 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 9 | eregli
# Processing Record 9 of Set 9 | gasa
# Processing Record 10 of Set 9 | la ronge
# Processing Record 11 of Set 9 | palana
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | buriti
# Processing Record 14 of Set 9 | plettenberg bay
# Processing Record 15 of Set 9 | sydney
# Processing Record 16 of Set 9 | baixo guandu
# Processing Record 17 of Set 9 | povenets
# Processing Record 18 of Set 9 | charlestown
# Processing Record 19 of Set 9 | santa helena
# Processing Record 20 of Set 9 | sept-iles
# Processing Record 21 of Set 9 | huarmey
# Processing Record 22 of Set 9 | utete
# Processing Record 23 of Set 9 | batangafo
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | orlik
# Processing Record 26 of Set 9 | calvinia
# Processing Record 27 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 9 | broken hill
# Processing Record 29 of Set 9 | turtas
# Processing Record 30 of Set 9 | laguna
# Processing Record 31 of Set 9 | yafran
# Processing Record 32 of Set 9 | tezu
# Processing Record 33 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 9 | kakonko
# Processing Record 35 of Set 9 | rorvik
# Processing Record 36 of Set 9 | sisian
# Processing Record 37 of Set 9 | pochutla
# Processing Record 38 of Set 9 | bako
# Processing Record 39 of Set 9 | amapa
# Processing Record 40 of Set 9 | maragogi
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | carballo
# Processing Record 43 of Set 9 | ilulissat
# Processing Record 44 of Set 9 | san pedro
# Processing Record 45 of Set 9 | kishapu
# Processing Record 46 of Set 9 | lohja
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 9 | imbituba
# Processing Record 50 of Set 9 | vestmanna
# Processing Record 1 of Set 10 | novi travnik
# Processing Record 2 of Set 10 | teguldet
# Processing Record 3 of Set 10 | north bend
# Processing Record 4 of Set 10 | haines junction
# Processing Record 5 of Set 10 | pisz
# Processing Record 6 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 10 | moose factory
# Processing Record 8 of Set 10 | poltavka
# Processing Record 9 of Set 10 | hede
# Processing Record 10 of Set 10 | eureka
# Processing Record 11 of Set 10 | caetite
# Processing Record 12 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 10 | ostersund
# Processing Record 14 of Set 10 | dvinskoy
# Processing Record 15 of Set 10 | chitipa
# Processing Record 16 of Set 10 | leiyang
# Processing Record 17 of Set 10 | merauke
# Processing Record 18 of Set 10 | betki
# City not found. Skipping...
# Processing Record 19 of Set 10 | yatou
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | yauya
# Processing Record 22 of Set 10 | roma
# Processing Record 23 of Set 10 | shingu
# Processing Record 24 of Set 10 | bukachacha
# Processing Record 25 of Set 10 | nago
# Processing Record 26 of Set 10 | banff
# Processing Record 27 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | peniche
# Processing Record 29 of Set 10 | fengzhen
# Processing Record 30 of Set 10 | vinh
# Processing Record 31 of Set 10 | ondarroa
# Processing Record 32 of Set 10 | dzhebariki-khaya
# Processing Record 33 of Set 10 | sioux lookout
# Processing Record 34 of Set 10 | cairns
# Processing Record 35 of Set 10 | cabo san lucas
# Processing Record 36 of Set 10 | gamba
# Processing Record 37 of Set 10 | ngunguru
# Processing Record 38 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 10 | mandan
# Processing Record 40 of Set 10 | minsk
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 43 of Set 10 | pundaguitan
# Processing Record 44 of Set 10 | general roca
# Processing Record 45 of Set 10 | lagunas
# Processing Record 46 of Set 10 | buin
# Processing Record 47 of Set 10 | muzhi
# Processing Record 48 of Set 10 | jerantut
# Processing Record 49 of Set 10 | rossland
# Processing Record 50 of Set 10 | tukrah
# Processing Record 1 of Set 11 | xining
# Processing Record 2 of Set 11 | sebrovo
# Processing Record 3 of Set 11 | lompoc
# Processing Record 4 of Set 11 | hassleholm
# Processing Record 5 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 11 | general pico
# Processing Record 7 of Set 11 | margate
# Processing Record 8 of Set 11 | bonoua
# Processing Record 9 of Set 11 | half moon bay
# Processing Record 10 of Set 11 | ucluelet
# Processing Record 11 of Set 11 | spruce grove
# Processing Record 12 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 11 | dunedin
# Processing Record 14 of Set 11 | aloleng
# Processing Record 15 of Set 11 | paso de los toros
# Processing Record 16 of Set 11 | basay
# Processing Record 17 of Set 11 | swidnik
# Processing Record 18 of Set 11 | okhotsk
# Processing Record 19 of Set 11 | san vicente
# Processing Record 20 of Set 11 | tokmak
# Processing Record 21 of Set 11 | flinders
# Processing Record 22 of Set 11 | paamiut
# Processing Record 23 of Set 11 | santiago
# Processing Record 24 of Set 11 | dalinghe
# City not found. Skipping...
# Processing Record 25 of Set 11 | mezen
# Processing Record 26 of Set 11 | rosarito
# Processing Record 27 of Set 11 | sao filipe
# Processing Record 28 of Set 11 | lima duarte
# Processing Record 29 of Set 11 | venado tuerto
# Processing Record 30 of Set 11 | sinnamary
# Processing Record 31 of Set 11 | jalu
# Processing Record 32 of Set 11 | solnechnyy
# Processing Record 33 of Set 11 | zhaozhou
# Processing Record 34 of Set 11 | saint-francois
# Processing Record 35 of Set 11 | buala
# Processing Record 36 of Set 11 | galesong
# Processing Record 37 of Set 11 | lukoyanov
# Processing Record 38 of Set 11 | klyuchi
# Processing Record 39 of Set 11 | inhambane
# Processing Record 40 of Set 11 | varna
# Processing Record 41 of Set 11 | urusha
# Processing Record 42 of Set 11 | vila franca do campo
# Processing Record 43 of Set 11 | teya
# Processing Record 44 of Set 11 | palmer
# Processing Record 45 of Set 11 | xam nua
# Processing Record 46 of Set 11 | carbonia
# Processing Record 47 of Set 11 | mayumba
# Processing Record 48 of Set 11 | osmena
# Processing Record 49 of Set 11 | dezful
# Processing Record 50 of Set 11 | dunmore east
# Processing Record 1 of Set 12 | dong hoi
# Processing Record 2 of Set 12 | hun
# Processing Record 3 of Set 12 | kangaatsiaq
# Processing Record 4 of Set 12 | kungurtug
# Processing Record 5 of Set 12 | kruisfontein
# Processing Record 6 of Set 12 | linares
# Processing Record 7 of Set 12 | los llanos de aridane
# Processing Record 8 of Set 12 | mitsamiouli
# Processing Record 9 of Set 12 | atasu
# Processing Record 10 of Set 12 | otane
# Processing Record 11 of Set 12 | jackson
# Processing Record 12 of Set 12 | baruun-urt
# Processing Record 13 of Set 12 | oneonta
# Processing Record 14 of Set 12 | xai-xai
# Processing Record 15 of Set 12 | bafq
# Processing Record 16 of Set 12 | billings
# Processing Record 17 of Set 12 | north myrtle beach
# Processing Record 18 of Set 12 | aguimes
# Processing Record 19 of Set 12 | hambantota
# Processing Record 20 of Set 12 | berlevag
# Processing Record 21 of Set 12 | atar
# Processing Record 22 of Set 12 | antofagasta
# Processing Record 23 of Set 12 | campbell river
# Processing Record 24 of Set 12 | thaton
# Processing Record 25 of Set 12 | hailar
# Processing Record 26 of Set 12 | ballina
# Processing Record 27 of Set 12 | vostok
# Processing Record 28 of Set 12 | caravelas
# Processing Record 29 of Set 12 | santa isabel do rio negro
# Processing Record 30 of Set 12 | diamantino
# Processing Record 31 of Set 12 | bosaso
# Processing Record 32 of Set 12 | cartagena del chaira
# Processing Record 33 of Set 12 | linjiang
# Processing Record 34 of Set 12 | gaogou
# Processing Record 35 of Set 12 | northam
# Processing Record 36 of Set 12 | khani
# Processing Record 37 of Set 12 | magadi
# Processing Record 38 of Set 12 | kuusamo
# Processing Record 39 of Set 12 | kokstad
# Processing Record 40 of Set 12 | esfarayen
# Processing Record 41 of Set 12 | lunenburg
# Processing Record 42 of Set 12 | presidencia roque saenz pena
# Processing Record 43 of Set 12 | deogarh
# Processing Record 44 of Set 12 | tevriz
# Processing Record 45 of Set 12 | kemijarvi
# Processing Record 46 of Set 12 | lamar
# Processing Record 47 of Set 12 | acajutla
# Processing Record 48 of Set 12 | puri
# Processing Record 49 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | catamarca
# Processing Record 1 of Set 13 | boa vista
# Processing Record 2 of Set 13 | thinadhoo
# Processing Record 3 of Set 13 | sterling
# Processing Record 4 of Set 13 | lanigan
# Processing Record 5 of Set 13 | chavakkad
# Processing Record 6 of Set 13 | blackwater
# Processing Record 7 of Set 13 | romny
# Processing Record 8 of Set 13 | luderitz
# Processing Record 9 of Set 13 | oxapampa
# Processing Record 10 of Set 13 | del rio
# Processing Record 11 of Set 13 | vilhena
# Processing Record 12 of Set 13 | matay
# Processing Record 13 of Set 13 | komsomolskiy
# Processing Record 14 of Set 13 | erzin
# Processing Record 15 of Set 13 | lannion
# Processing Record 16 of Set 13 | salsomaggiore terme
# Processing Record 17 of Set 13 | karakol
# Processing Record 18 of Set 13 | vyartsilya
# Processing Record 19 of Set 13 | hanmer springs
# Processing Record 20 of Set 13 | nome
# Processing Record 21 of Set 13 | college
# Processing Record 22 of Set 13 | berkak
# Processing Record 23 of Set 13 | chardara
# Processing Record 24 of Set 13 | frankfort
# Processing Record 25 of Set 13 | maldonado
# Processing Record 26 of Set 13 | mogadishu
# Processing Record 27 of Set 13 | ugoofaaru
# Processing Record 28 of Set 13 | swakopmund
# Processing Record 29 of Set 13 | lexington park
# Processing Record 30 of Set 13 | gemena
# Processing Record 31 of Set 13 | portland
# Processing Record 32 of Set 13 | delta
# Processing Record 33 of Set 13 | grand forks
# Processing Record 34 of Set 13 | khvalynsk
# Processing Record 35 of Set 13 | alta floresta
# Processing Record 36 of Set 13 | mafra
# Processing Record 37 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 13 | juneau
# Processing Record 39 of Set 13 | odesskoye
# Processing Record 40 of Set 13 | saint-georges
# Processing Record 41 of Set 13 | narsaq
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | kirkwall
# Processing Record 44 of Set 13 | taunggyi
# Processing Record 45 of Set 13 | quang ngai
# Processing Record 46 of Set 13 | vanimo
# Processing Record 47 of Set 13 | los altos
# Processing Record 48 of Set 13 | lae
# Processing Record 49 of Set 13 | porto-vecchio
# Processing Record 50 of Set 13 | jiuquan
# Processing Record 1 of Set 14 | nouadhibou
# Processing Record 2 of Set 14 | kampot
# Processing Record 3 of Set 14 | shahrud
# Processing Record 4 of Set 14 | atbasar
# Processing Record 5 of Set 14 | aberdeen
# Processing Record 6 of Set 14 | bogale
# Processing Record 7 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 14 | maniitsoq
# Processing Record 9 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 14 | mutoko
# Processing Record 11 of Set 14 | banda aceh
# Processing Record 12 of Set 14 | bilibino
# Processing Record 13 of Set 14 | san quintin
# Processing Record 14 of Set 14 | bahraich
# Processing Record 15 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 16 of Set 14 | roanoke rapids
# Processing Record 17 of Set 14 | beatrice
# Processing Record 18 of Set 14 | kathu
# Processing Record 19 of Set 14 | conselheiro pena
# Processing Record 20 of Set 14 | salinas
# Processing Record 21 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 14 | batu
# Processing Record 23 of Set 14 | danilovka
# Processing Record 24 of Set 14 | saeby
# Processing Record 25 of Set 14 | kaitangata
# Processing Record 26 of Set 14 | sawtell
# Processing Record 27 of Set 14 | liverpool
# Processing Record 28 of Set 14 | langsa
# Processing Record 29 of Set 14 | kimbe
# Processing Record 30 of Set 14 | yining
# Processing Record 31 of Set 14 | uvira
# Processing Record 32 of Set 14 | burnie
# Processing Record 33 of Set 14 | broome
# Processing Record 34 of Set 14 | xinzhi
# Processing Record 35 of Set 14 | port-gentil
# Processing Record 36 of Set 14 | kysyl-syr
# Processing Record 37 of Set 14 | dubna
# Processing Record 38 of Set 14 | quebo
# Processing Record 39 of Set 14 | dudinka
# Processing Record 40 of Set 14 | labuan
# Processing Record 41 of Set 14 | goderich
# Processing Record 42 of Set 14 | excelsior springs
# Processing Record 43 of Set 14 | touros
# Processing Record 44 of Set 14 | oksovskiy
# Processing Record 45 of Set 14 | khowai
# Processing Record 46 of Set 14 | alcaniz
# Processing Record 47 of Set 14 | junction city
# Processing Record 48 of Set 14 | saint-joseph
# Processing Record 49 of Set 14 | ulaanbaatar
# Processing Record 50 of Set 14 | itoman
# Processing Record 1 of Set 15 | kota bahru
# Processing Record 2 of Set 15 | zabol
# Processing Record 3 of Set 15 | alenquer
# Processing Record 4 of Set 15 | zhigansk
# Processing Record 5 of Set 15 | timra
# Processing Record 6 of Set 15 | mayor pablo lagerenza
# Processing Record 7 of Set 15 | zunyi
# Processing Record 8 of Set 15 | upington
# Processing Record 9 of Set 15 | puerto berrio
# Processing Record 10 of Set 15 | constitucion
# Processing Record 11 of Set 15 | moerai
# Processing Record 12 of Set 15 | dan khun thot
# Processing Record 13 of Set 15 | verrettes
# Processing Record 14 of Set 15 | kuah
# Processing Record 15 of Set 15 | sindor
# Processing Record 16 of Set 15 | angoram
# Processing Record 17 of Set 15 | tahoua
# Processing Record 18 of Set 15 | aranos
# Processing Record 19 of Set 15 | kalmar
# Processing Record 20 of Set 15 | nizhneudinsk
# Processing Record 21 of Set 15 | luanda
# Processing Record 22 of Set 15 | el cortezo
# Processing Record 23 of Set 15 | parras
# City not found. Skipping...
# Processing Record 24 of Set 15 | egvekinot
# Processing Record 25 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 15 | amparafaravola
# Processing Record 27 of Set 15 | black river
# Processing Record 28 of Set 15 | ratnagiri
# Processing Record 29 of Set 15 | lusambo
# Processing Record 30 of Set 15 | pombas
# Processing Record 31 of Set 15 | port shepstone
# Processing Record 32 of Set 15 | gravdal
# Processing Record 33 of Set 15 | tautira
# Processing Record 34 of Set 15 | arlit
# Processing Record 35 of Set 15 | samfya
# Processing Record 36 of Set 15 | matagami
# Processing Record 37 of Set 15 | salamiyah
# Processing Record 38 of Set 15 | ust-uda
# Processing Record 39 of Set 15 | bira
# Processing Record 40 of Set 15 | almaznyy
# Processing Record 41 of Set 15 | san jose
# Processing Record 42 of Set 15 | hovd
# Processing Record 43 of Set 15 | kiknur
# Processing Record 44 of Set 15 | ola
# Processing Record 45 of Set 15 | sibu
# Processing Record 46 of Set 15 | twin falls
# Processing Record 47 of Set 15 | dandong
# Processing Record 48 of Set 15 | partenit
# Processing Record 49 of Set 15 | dolores
# Processing Record 50 of Set 15 | corinth
# Processing Record 1 of Set 16 | elizabeth city
# Processing Record 2 of Set 16 | harper
# Processing Record 3 of Set 16 | wattegama
# Processing Record 4 of Set 16 | marfino
# Processing Record 5 of Set 16 | beinamar
# Processing Record 6 of Set 16 | balakhninskiy
# Processing Record 7 of Set 16 | saint-augustin
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert to dataframe. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     56.08        68          98
# 1       Castro      BR -24.7911  -50.0119     58.26        67           0
# 2     Liseleje      DK  56.0053   11.9483     68.83        77          45
# 3  Yellowknife      CA  62.4560 -114.3525     56.32        50          75
# 4     Bengkulu      ID  -3.8004  102.2655     74.93        87          31
# 5      Rikitea      PF -23.1203 -134.9692     69.22        54           0
# 6      Halifax      CA  44.6453  -63.5724     73.53        69          64
# 7  New Norfolk      AU -42.7826  147.0587     43.92        71          76
# 8         Amot      NO  59.5714    7.9877     57.51        77          10
# 9     Hermanus      ZA -34.4187   19.2345     51.91        57          13
#
#    Wind Speed Current Description
# 0       16.08     overcast clouds
# 1        3.62           clear sky
# 2        5.99    scattered clouds
# 3        1.99       broken clouds
# 4        4.61    scattered clouds
# 5        1.21           clear sky
# 6        5.01       broken clouds
# 7        3.00          light rain
# 8        2.19           clear sky
# 9        4.79          few clouds

# %%
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Export to CSV.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
